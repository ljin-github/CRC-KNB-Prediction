# %% [markdown]
# # 读取DataPattern下的文件
#
# 注意：所有JPG图像都会被认为是训练集。

# %%
import os
import pandas as pd

from onekey_algo import OnekeyDS as okds
from onekey_algo import get_param_in_cwd

data_pattern = r'C:\patches\topatches' 
patches = []
for r, ds, fs in os.walk(data_pattern):
    patches.extend([os.path.join(r, p) for p in fs if p.endswith('.jpg')])

patches = pd.DataFrame(patches, columns=['fpath'])
patches['fname'] = patches['fpath'].map(lambda x: os.path.basename(x))

def map2id(x):
    x = os.path.basename(x)
    *fname_items, w, h, ltx, lty, rbx, rby = x.split('_')
    return '_'.join(fname_items)
patches['ID'] = patches['fpath'].map(map2id)
patches

# %% [markdown]
# # 获取划分的数据集

# %%
label_f = pd.read_csv( r'D:\result\split_info\label-RND-0_wsi.csv', dtype={'ID': str})
label_f['ID'] = label_f['ID'].map(lambda x: str(x))
patches = pd.merge(patches, label_f, on='ID', how='inner')
patches

# print(label_f['group'].unique())
# Out:
#                                                       fpath  \
# 0         C:\patches\topatches\negative\1936292-3\193629...
# 1         C:\patches\topatches\negative\1936292-3\193629...
# 2         C:\patches\topatches\negative\1936292-3\193629...
# 3         C:\patches\topatches\negative\1936292-3\193629...
# 4         C:\patches\topatches\negative\1936292-3\193629...
# ...                                                     ...
# 14931782  C:\patches\topatches\pasitive\2340123-9\234012...
# 14931783  C:\patches\topatches\pasitive\2340123-9\234012...
# 14931784  C:\patches\topatches\pasitive\2340123-9\234012...
# 14931785  C:\patches\topatches\pasitive\2340123-9\234012...
# 14931786  C:\patches\topatches\pasitive\2340123-9\234012...
#
#                                                       fname         ID  label  \
# 0         1936292-3_65024_53760_10240_10240_10752_10752.jpg  1936292-3      0
# 1         1936292-3_65024_53760_10240_10752_10752_11264.jpg  1936292-3      0
# 2         1936292-3_65024_53760_10240_11264_10752_11776.jpg  1936292-3      0
# 3         1936292-3_65024_53760_10240_11776_10752_12288.jpg  1936292-3      0
# 4         1936292-3_65024_53760_10240_12288_10752_12800.jpg  1936292-3      0
# ...                                                     ...        ...    ...
# 14931782   2340123-9_77312_62976_9728_56832_10240_57344.jpg  2340123-9      1
# 14931783   2340123-9_77312_62976_9728_57344_10240_57856.jpg  2340123-9      1
# 14931784   2340123-9_77312_62976_9728_57856_10240_58368.jpg  2340123-9      1
# 14931785   2340123-9_77312_62976_9728_58368_10240_58880.jpg  2340123-9      1
# 14931786   2340123-9_77312_62976_9728_58880_10240_59392.jpg  2340123-9      1
#
#           group
# 0         train
# 1         train
# 2         train
# 3         train
# 4         train
# ...         ...
# 14931782   test
# 14931783   test
# 14931784   test
# 14931785   test
# 14931786   test
#
# [14931787 rows x 5 columns]

# %% [markdown]
# # 保存List模式数据

# %%
import numpy as np

ugroups = np.unique(patches['group'])
for group in ugroups:
    group_info = 'train' if group == 'train' else 'val'
    patches[patches['group'] == group][['fpath', 'label']].to_csv(os.path.join(r'D:\result\split_info', f'{group_info}.txt'), 
                                                                  index=False, header=False, sep='\t')
    
    print(label_f['label'].unique())
# Out:
# [1 0]
# [1 0]

# %%
# Out:
# 表a的表头:
# ['\ufeffID', 'label', 'group']
#
# 表a的前5行数据:
# ['2020784-4.svs', '1', 'train']
# ['2033125-5.svs', '1', 'train']
# ['2128057-5.svs', '0', 'train']
# ['2015858-5.svs', '1', 'train']
# ['2113234-5.svs', '0', 'train']
#
# 表a的行数: 1595
# 表a的列数: 3
