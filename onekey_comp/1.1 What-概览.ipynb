# %% [markdown]
# # What
# 分类任务，支持两种模式
# 1. Folder模式，需要输入`train`, `valid`两个测试集对应的目录。`labels.txt`，需要训练的label，里面每个类别一行。
# 2. List模式，需要输入`train`, `valid`两个测试集对应的训练文件，每行一个样本。`labels.txt`是可选参数，里面每个类别一行。`data_pattern`一个通用的目录，与train、val中的第一列进行拼接。

# %%
# ## 获得视频教程
# from onekey_algo.custom.Manager import onekey_show
# onekey_show('What概览')

# %%
# ## 获得视频教程
# from onekey_algo.custom.Manager import onekey_show
# onekey_show('labelme-what2d')

# %% [markdown]
# ### Labelme数据标注
#
# 这里我们以【皮肤黑色素瘤类型诊断】数据为例，启动labelme之前，需要先修改labelme的启动选项，或者在命令行启动labelme。
#
# #### 1、修改启动选项。
#
# 1. 右键labelme，属性。
# 2. 在 `目标(T)`选项中添加 `--flags`参数，记得中间用空格隔开。
#
#    ```shell
#    "C:\Program Files\labelme\labelme.exe"
#    ```
#
#    修改之后，在 `flags`参数之后，添加需要分类的标签。尽量用英文标签，用 `英文`逗号分开所有的标签。（--flags前面2个减号）
#
#    ```shell
#    "C:\Program Files\labelme\labelme.exe" --flags label1,label2,labeln
#    ```
# 3. 确定退出，双击打开。
#
# #### 2、加载标注数据，开始标注
#
# ![attachmentId-133](http://medai.icu/storage/attachments/2021/12/05/ohR48IdCEJgEp9CZBLVDWVorjmj9mPk11uQ0ZebE.png)

# %%
# ## 获得视频教程
# from onekey_algo.custom.Manager import onekey_show
# onekey_show('What概览|数据转化')

# %%
# import os
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# from onekey_algo.scripts.core import clf_covert2rec

# input_dir = r'标注数据目录'
# save_dir = r'标注数据输出目录'
# partition = [0.8, 0.2]

# clf_covert2rec(input_dir, save_dir = save_dir, partition = partition)

# %% [markdown]
# ### 支持的模型名称
#
# 模型名称替换代码中的 `model_name`变量的值。
#
# | **模型系列** | **模型名称**                                                 |
# | ------------ | ------------------------------------------------------------ |
# | AlexNet      | alexnet                                                      |
# | VGG          | vgg11, vgg11_bn, vgg13, vgg13_bn, vgg16, vgg16_bn, vgg19_bn, vgg19 |
# | ResNet       | resnet18, resnet34, resnet50, resnet101, resnet152, resnext50_32x4d, resnext101_32x8d, wide_resnet50_2, wide_resnet101_2 |
# | DenseNet     | densenet121, densenet169, densenet201, densenet161           |
# | Inception    | googlenet, inception_v3                                      |
# | SqueezeNet   | squeezenet1_0, squeezenet1_1                                 |
# | ShuffleNetV2 | shufflenet_v2_x2_0, shufflenet_v2_x0_5, shufflenet_v2_x1_0, shufflenet_v2_x1_5 |
# | MobileNet    | mobilenet_v2, mobilenet_v3_large, mobilenet_v3_small         |
# | MNASNet      | mnasnet0_5, mnasnet0_75, mnasnet1_0, mnasnet1_3              |
# | ViT       | ViT, SimpleViT|
#
# ![](http://medai.icu/storage/attachments/2023/10/10/RHd9eH5U67VsOP8vqyNyBD5nGYREejkAKx3Jw16X.)

# %% [markdown]
# ### List模式
#
# 在Onekey中List模式一般是采用labelme标注出来的结果，如果要使用自己的数据应用List模式，需要根据自己的实际情况对数据进行处理。
#
# * `train.txt`，训练数据列表，中间用\t（Tab水平制表符）进行分割。
# * `val.txt`，验证数据列表，中间用\t（Tab水平制表符）进行分割。
# * `labels.txt`，label的集合，表明训练数据多少标签。
# * `data_pattern`参数，所有数据存在的目录的公共前缀，如果`train.txt`,`val.txt`文件里面存放的是绝对路径，`data_pattern`设置为None即可。

# %%
# ## 获得视频教程
# from onekey_algo.custom.Manager import onekey_show
# onekey_show('What概览|List')

# %%
import os
from onekey_algo.classification.run_classification import main as clf_main
from collections import namedtuple

# 设置参数
save_dir = r'C:\Users\Administrator\Desktop\test\data'
train_f = os.path.join(save_dir, 'deleted_train-RND-0.txt')
val_f = os.path.join(save_dir, 'deleted_val-RND-0.txt')
labels_f = os.path.join(save_dir, 'labels.txt')
data_pattern = r'C:\Users\Administrator\Desktop\test\data\topatches'

params = dict(train=train_f,
              valid=val_f,
              labels_file=labels_f,
              data_pattern=data_pattern,
              j=10,
              max2use=None,
              val_max2use=None,
              batch_balance=False,
              normalize_method='imagenet',
              model_name='resnet18',
              vit_settings = {'patch_size': 64, 'dim': 1024, 'depth': 6, 'heads': 16, 'mlp_dim': 2048},
              gpus=[0],
              batch_size=120,
              epochs=5,
              init_lr=0.01,
              optimizer='sgd',
              retrain=None,
              model_root='.',
              add_date=False,
              iters_start=0,
              iters_verbose=256,
              save_per_epoch=False,
              pretrained=True)
# 训练模型
Args = namedtuple("Args", params)
clf_main(Args(**params))
# Out:
# [2024-10-12 09:48:42 - <frozen onekey_algo.datasets.ClassificationDataset>: 662]	INFO	WE RECOMMEND YOU USE SPECIFY dataset_name LIKE list for ListDataset OR folder for FolderDataset.
# [2024-10-12 09:48:42 - <frozen onekey_algo.datasets.ClassificationDataset>:  83]	INFO	Parsing record file C:\Users\Administrator\Desktop\test\data\deleted_train-RND-0.txt
# [2024-10-12 09:48:58 - <frozen onekey_algo.datasets.ClassificationDataset>:  86]	INFO		Checking file exists in C:\Users\Administrator\Desktop\test\data\deleted_train-RND-0.txt
# [2024-10-12 10:06:22 - <frozen onekey_algo.datasets.ClassificationDataset>: 673]	INFO	We infer your kwargs to be <class 'onekey_algo.datasets.ClassificationDataset.ListDataset'>.
# [2024-10-12 10:06:22 - <frozen onekey_algo.datasets.ClassificationDataset>: 662]	INFO	WE RECOMMEND YOU USE SPECIFY dataset_name LIKE list for ListDataset OR folder for FolderDataset.
# [2024-10-12 10:06:22 - <frozen onekey_algo.datasets.ClassificationDataset>:  83]	INFO	Parsing record file C:\Users\Administrator\Desktop\test\data\deleted_val-RND-0.txt
# [2024-10-12 10:06:25 - <frozen onekey_algo.datasets.ClassificationDataset>:  86]	INFO		Checking file exists in C:\Users\Administrator\Desktop\test\data\deleted_val-RND-0.txt
# [2024-10-12 10:10:26 - <frozen onekey_algo.datasets.ClassificationDataset>: 673]	INFO	We infer your kwargs to be <class 'onekey_algo.datasets.ClassificationDataset.ListDataset'>.
# [2024-10-12 10:10:26 - <frozen onekey_algo.utils.about_log>: 149]	INFO	Train:Dataset is ListDataset
# [2024-10-12 10:10:26 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Number of samples: 12106865
# [2024-10-12 10:10:26 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Root location: C:\Users\Administrator\Desktop\test\data\topatches
# [2024-10-12 10:10:26 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Labels file is stored in C:\Users\Administrator\Desktop\test\data\labels.txt
# [2024-10-12 10:10:26 - <frozen onekey_algo.utils.about_log>: 149]	INFO	Valid:Dataset is ListDataset
# [2024-10-12 10:10:26 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Number of samples: 3049444
# [2024-10-12 10:10:26 - <frozen onekey_algo.utils.about_log>: 149]	INFO		Root location: C:\Users\Administrator\Desktop\test\data\topatches
# [2024-10-12 10:10:26 - <frozen onekey_algo.classification.run_classification>: 323]	INFO	Creating model resnet18...
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\Administrator/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# [2024-10-12 10:10:28 - <frozen onekey_algo.classification.run_classification>: 370]	INFO	Start training...
# [2024-10-12 10:13:46 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.003,256	LR: 0.010000	Loss: 0.000	Acc: 100.0000	 Speed: 155.44 img/s	Time: 0hrs:3min
# [2024-10-12 10:14:21 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.005,512	LR: 0.010000	Loss: 0.000	Acc: 100.0000	 Speed: 880.80 img/s	Time: 0hrs:3min
# [2024-10-12 10:14:55 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.008,768	LR: 0.010000	Loss: 0.000	Acc: 100.0000	 Speed: 900.54 img/s	Time: 0hrs:4min
# [2024-10-12 10:15:28 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.010,1024	LR: 0.010000	Loss: 0.000	Acc: 100.0000	 Speed: 915.43 img/s	Time: 0hrs:5min
# [2024-10-12 10:16:03 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.013,1280	LR: 0.010000	Loss: 0.000	Acc: 100.0000	 Speed: 893.33 img/s	Time: 0hrs:5min
# [2024-10-12 10:16:38 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.015,1536	LR: 0.010000	Loss: 0.000	Acc: 100.0000	 Speed: 873.24 img/s	Time: 0hrs:6min
# [2024-10-12 10:17:12 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.018,1792	LR: 0.010000	Loss: 0.000	Acc: 100.0000	 Speed: 910.17 img/s	Time: 0hrs:6min
# [2024-10-12 10:17:46 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.020,2048	LR: 0.010000	Loss: 0.000	Acc: 100.0000	 Speed: 895.08 img/s	Time: 0hrs:7min
# [2024-10-12 10:18:21 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.023,2304	LR: 0.009999	Loss: 0.000	Acc: 100.0000	 Speed: 886.45 img/s	Time: 0hrs:7min
# [2024-10-12 10:18:56 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.025,2560	LR: 0.009999	Loss: 0.000	Acc: 100.0000	 Speed: 869.61 img/s	Time: 0hrs:8min
# [2024-10-12 10:19:31 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.028,2816	LR: 0.009999	Loss: 0.000	Acc: 100.0000	 Speed: 883.55 img/s	Time: 0hrs:9min
# [2024-10-12 10:20:05 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.030,3072	LR: 0.009999	Loss: 0.000	Acc: 100.0000	 Speed: 889.20 img/s	Time: 0hrs:9min
# [2024-10-12 10:20:41 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.033,3328	LR: 0.009999	Loss: 0.000	Acc: 100.0000	 Speed: 871.02 img/s	Time: 0hrs:10min
# [2024-10-12 10:21:16 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.036,3584	LR: 0.009999	Loss: 0.000	Acc: 100.0000	 Speed: 860.29 img/s	Time: 0hrs:10min
# [2024-10-12 10:21:51 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.038,3840	LR: 0.009999	Loss: 0.000	Acc: 100.0000	 Speed: 886.06 img/s	Time: 0hrs:11min
# [2024-10-12 10:22:25 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.041,4096	LR: 0.009998	Loss: 0.000	Acc: 100.0000	 Speed: 901.80 img/s	Time: 0hrs:11min
# [2024-10-12 10:23:00 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.043,4352	LR: 0.009998	Loss: 0.000	Acc: 100.0000	 Speed: 890.36 img/s	Time: 0hrs:12min
# [2024-10-12 10:23:35 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.046,4608	LR: 0.009998	Loss: 0.000	Acc: 100.0000	 Speed: 861.13 img/s	Time: 0hrs:13min
# [2024-10-12 10:24:10 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.048,4864	LR: 0.009998	Loss: 0.000	Acc: 100.0000	 Speed: 893.17 img/s	Time: 0hrs:13min
# [2024-10-12 10:24:44 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.051,5120	LR: 0.009997	Loss: 0.000	Acc: 100.0000	 Speed: 899.61 img/s	Time: 0hrs:14min
# [2024-10-12 10:25:19 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.053,5376	LR: 0.009997	Loss: 0.000	Acc: 100.0000	 Speed: 873.92 img/s	Time: 0hrs:14min
# [2024-10-12 10:25:54 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.056,5632	LR: 0.009997	Loss: 0.000	Acc: 100.0000	 Speed: 874.57 img/s	Time: 0hrs:15min
# [2024-10-12 10:26:29 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.058,5888	LR: 0.009997	Loss: 0.000	Acc: 100.0000	 Speed: 875.24 img/s	Time: 0hrs:16min
# [2024-10-12 10:27:04 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.061,6144	LR: 0.009996	Loss: 0.000	Acc: 100.0000	 Speed: 882.46 img/s	Time: 0hrs:16min
# [2024-10-12 10:27:40 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.063,6400	LR: 0.009996	Loss: 0.000	Acc: 100.0000	 Speed: 864.84 img/s	Time: 0hrs:17min
# [2024-10-12 10:28:16 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.066,6656	LR: 0.009996	Loss: 0.000	Acc: 100.0000	 Speed: 846.02 img/s	Time: 0hrs:17min
# [2024-10-12 10:28:51 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.069,6912	LR: 0.009995	Loss: 0.000	Acc: 100.0000	 Speed: 867.77 img/s	Time: 0hrs:18min
# [2024-10-12 10:29:27 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.071,7168	LR: 0.009995	Loss: 0.000	Acc: 100.0000	 Speed: 854.92 img/s	Time: 0hrs:18min
# [2024-10-12 10:30:03 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.074,7424	LR: 0.009995	Loss: 0.000	Acc: 100.0000	 Speed: 851.98 img/s	Time: 0hrs:19min
# [2024-10-12 10:30:39 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.076,7680	LR: 0.009994	Loss: 0.000	Acc: 100.0000	 Speed: 858.00 img/s	Time: 0hrs:20min
# [2024-10-12 10:31:14 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.079,7936	LR: 0.009994	Loss: 0.000	Acc: 100.0000	 Speed: 869.39 img/s	Time: 0hrs:20min
# [2024-10-12 10:31:51 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.081,8192	LR: 0.009993	Loss: 0.000	Acc: 100.0000	 Speed: 844.00 img/s	Time: 0hrs:21min
# [2024-10-12 10:32:28 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.084,8448	LR: 0.009993	Loss: 0.000	Acc: 100.0000	 Speed: 824.79 img/s	Time: 0hrs:21min
# [2024-10-12 10:33:07 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.086,8704	LR: 0.009993	Loss: 0.000	Acc: 100.0000	 Speed: 790.95 img/s	Time: 0hrs:22min
# [2024-10-12 10:33:44 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.089,8960	LR: 0.009992	Loss: 0.000	Acc: 100.0000	 Speed: 832.60 img/s	Time: 0hrs:23min
# [2024-10-12 10:34:20 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.091,9216	LR: 0.009992	Loss: 0.000	Acc: 100.0000	 Speed: 858.05 img/s	Time: 0hrs:23min
# [2024-10-12 10:34:57 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.094,9472	LR: 0.009991	Loss: 0.000	Acc: 100.0000	 Speed: 825.16 img/s	Time: 0hrs:24min
# [2024-10-12 10:35:35 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.096,9728	LR: 0.009991	Loss: 0.000	Acc: 100.0000	 Speed: 808.40 img/s	Time: 0hrs:25min
# [2024-10-12 10:36:12 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.099,9984	LR: 0.009990	Loss: 0.000	Acc: 100.0000	 Speed: 826.45 img/s	Time: 0hrs:25min
# [2024-10-12 10:36:48 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.101,10240	LR: 0.009990	Loss: 0.000	Acc: 100.0000	 Speed: 849.32 img/s	Time: 0hrs:26min
# [2024-10-12 10:37:25 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.104,10496	LR: 0.009989	Loss: 0.000	Acc: 100.0000	 Speed: 824.83 img/s	Time: 0hrs:26min
# [2024-10-12 10:38:04 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.107,10752	LR: 0.009989	Loss: 0.000	Acc: 100.0000	 Speed: 800.21 img/s	Time: 0hrs:27min
# [2024-10-12 10:38:41 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.109,11008	LR: 0.009988	Loss: 0.000	Acc: 100.0000	 Speed: 836.56 img/s	Time: 0hrs:28min
# [2024-10-12 10:39:17 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.112,11264	LR: 0.009988	Loss: 0.000	Acc: 100.0000	 Speed: 845.37 img/s	Time: 0hrs:28min
# [2024-10-12 10:39:55 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.114,11520	LR: 0.009987	Loss: 0.000	Acc: 100.0000	 Speed: 813.56 img/s	Time: 0hrs:29min
# [2024-10-12 10:40:31 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.117,11776	LR: 0.009987	Loss: 0.000	Acc: 100.0000	 Speed: 843.82 img/s	Time: 0hrs:30min
# [2024-10-12 10:41:08 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.119,12032	LR: 0.009986	Loss: 0.000	Acc: 100.0000	 Speed: 829.93 img/s	Time: 0hrs:30min
# [2024-10-12 10:41:46 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.122,12288	LR: 0.009985	Loss: 0.000	Acc: 100.0000	 Speed: 800.79 img/s	Time: 0hrs:31min
# [2024-10-12 10:42:24 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.124,12544	LR: 0.009985	Loss: 0.000	Acc: 100.0000	 Speed: 818.04 img/s	Time: 0hrs:31min
# [2024-10-12 10:43:01 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.127,12800	LR: 0.009984	Loss: 0.000	Acc: 100.0000	 Speed: 832.12 img/s	Time: 0hrs:32min
# [2024-10-12 10:43:38 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.129,13056	LR: 0.009983	Loss: 0.000	Acc: 100.0000	 Speed: 822.33 img/s	Time: 0hrs:33min
# [2024-10-12 10:44:16 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.132,13312	LR: 0.009983	Loss: 0.000	Acc: 100.0000	 Speed: 810.17 img/s	Time: 0hrs:33min
# [2024-10-12 10:44:57 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.134,13568	LR: 0.009982	Loss: 0.000	Acc: 100.0000	 Speed: 754.75 img/s	Time: 0hrs:34min
# [2024-10-12 10:45:38 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.137,13824	LR: 0.009981	Loss: 0.000	Acc: 100.0000	 Speed: 755.06 img/s	Time: 0hrs:35min
# [2024-10-12 10:46:19 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.140,14080	LR: 0.009981	Loss: 0.000	Acc: 100.0000	 Speed: 749.07 img/s	Time: 0hrs:35min
# [2024-10-12 10:46:57 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.142,14336	LR: 0.009980	Loss: 0.000	Acc: 100.0000	 Speed: 798.86 img/s	Time: 0hrs:36min
# [2024-10-12 10:47:35 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.145,14592	LR: 0.009979	Loss: 0.000	Acc: 100.0000	 Speed: 800.88 img/s	Time: 0hrs:37min
# [2024-10-12 10:48:15 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.147,14848	LR: 0.009979	Loss: 0.000	Acc: 100.0000	 Speed: 773.76 img/s	Time: 0hrs:37min
# [2024-10-12 10:48:53 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.150,15104	LR: 0.009978	Loss: 0.000	Acc: 100.0000	 Speed: 805.77 img/s	Time: 0hrs:38min
# [2024-10-12 10:49:31 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.152,15360	LR: 0.009977	Loss: 0.000	Acc: 100.0000	 Speed: 813.40 img/s	Time: 0hrs:39min
# [2024-10-12 10:50:09 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.155,15616	LR: 0.009976	Loss: 0.000	Acc: 100.0000	 Speed: 816.82 img/s	Time: 0hrs:39min
# [2024-10-12 10:50:47 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.157,15872	LR: 0.009976	Loss: 0.000	Acc: 100.0000	 Speed: 804.57 img/s	Time: 0hrs:40min
# [2024-10-12 10:51:24 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.160,16128	LR: 0.009975	Loss: 0.000	Acc: 100.0000	 Speed: 833.08 img/s	Time: 0hrs:40min
# [2024-10-12 10:51:59 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.162,16384	LR: 0.009974	Loss: 0.000	Acc: 100.0000	 Speed: 860.75 img/s	Time: 0hrs:41min
# [2024-10-12 10:52:35 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.165,16640	LR: 0.009973	Loss: 0.000	Acc: 100.0000	 Speed: 852.20 img/s	Time: 0hrs:42min
# [2024-10-12 10:53:14 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.167,16896	LR: 0.009972	Loss: 0.000	Acc: 100.0000	 Speed: 788.42 img/s	Time: 0hrs:42min
# [2024-10-12 10:53:55 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.170,17152	LR: 0.009972	Loss: 0.000	Acc: 100.0000	 Speed: 761.22 img/s	Time: 0hrs:43min
# [2024-10-12 10:54:34 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.173,17408	LR: 0.009971	Loss: 0.000	Acc: 100.0000	 Speed: 777.96 img/s	Time: 0hrs:44min
# [2024-10-12 10:55:14 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.175,17664	LR: 0.009970	Loss: 0.000	Acc: 100.0000	 Speed: 777.77 img/s	Time: 0hrs:44min
# [2024-10-12 10:55:52 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.178,17920	LR: 0.009969	Loss: 0.000	Acc: 100.0000	 Speed: 795.32 img/s	Time: 0hrs:45min
# [2024-10-12 10:56:30 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.180,18176	LR: 0.009968	Loss: 0.000	Acc: 100.0000	 Speed: 814.49 img/s	Time: 0hrs:46min
# [2024-10-12 10:57:09 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.183,18432	LR: 0.009967	Loss: 0.000	Acc: 100.0000	 Speed: 779.26 img/s	Time: 0hrs:46min
# [2024-10-12 10:57:48 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.185,18688	LR: 0.009966	Loss: 0.000	Acc: 100.0000	 Speed: 787.27 img/s	Time: 0hrs:47min
# [2024-10-12 10:58:25 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.188,18944	LR: 0.009965	Loss: 0.000	Acc: 100.0000	 Speed: 844.79 img/s	Time: 0hrs:47min
# [2024-10-12 10:59:01 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.190,19200	LR: 0.009964	Loss: 0.000	Acc: 100.0000	 Speed: 853.43 img/s	Time: 0hrs:48min
# [2024-10-12 10:59:38 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.193,19456	LR: 0.009963	Loss: 0.000	Acc: 100.0000	 Speed: 830.00 img/s	Time: 0hrs:49min
# [2024-10-12 11:00:14 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.195,19712	LR: 0.009962	Loss: 0.000	Acc: 100.0000	 Speed: 853.80 img/s	Time: 0hrs:49min
# [2024-10-12 11:00:50 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.198,19968	LR: 0.009961	Loss: 0.000	Acc: 100.0000	 Speed: 839.94 img/s	Time: 0hrs:50min
# [2024-10-12 11:01:27 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.200,20224	LR: 0.009960	Loss: 0.000	Acc: 100.0000	 Speed: 849.77 img/s	Time: 0hrs:50min
# [2024-10-12 11:02:03 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.203,20480	LR: 0.009959	Loss: 0.000	Acc: 100.0000	 Speed: 839.37 img/s	Time: 0hrs:51min
# [2024-10-12 11:02:40 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.206,20736	LR: 0.009958	Loss: 0.000	Acc: 100.0000	 Speed: 838.04 img/s	Time: 0hrs:52min
# [2024-10-12 11:03:18 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.208,20992	LR: 0.009957	Loss: 0.000	Acc: 100.0000	 Speed: 802.32 img/s	Time: 0hrs:52min
# [2024-10-12 11:03:55 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.211,21248	LR: 0.009956	Loss: 0.000	Acc: 100.0000	 Speed: 839.50 img/s	Time: 0hrs:53min
# [2024-10-12 11:04:31 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.213,21504	LR: 0.009955	Loss: 0.000	Acc: 100.0000	 Speed: 851.54 img/s	Time: 0hrs:54min
# [2024-10-12 11:05:07 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.216,21760	LR: 0.009954	Loss: 0.000	Acc: 100.0000	 Speed: 850.03 img/s	Time: 0hrs:54min
# [2024-10-12 11:05:44 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.218,22016	LR: 0.009953	Loss: 0.000	Acc: 100.0000	 Speed: 837.58 img/s	Time: 0hrs:55min
# [2024-10-12 11:06:21 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.221,22272	LR: 0.009952	Loss: 0.000	Acc: 100.0000	 Speed: 812.46 img/s	Time: 0hrs:55min
# [2024-10-12 11:06:57 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.223,22528	LR: 0.009951	Loss: 0.000	Acc: 100.0000	 Speed: 858.31 img/s	Time: 0hrs:56min
# [2024-10-12 11:07:34 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.226,22784	LR: 0.009950	Loss: 0.000	Acc: 100.0000	 Speed: 827.97 img/s	Time: 0hrs:57min
# [2024-10-12 11:08:13 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.228,23040	LR: 0.009949	Loss: 0.000	Acc: 100.0000	 Speed: 796.72 img/s	Time: 0hrs:57min
# [2024-10-12 11:08:49 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.231,23296	LR: 0.009947	Loss: 0.000	Acc: 100.0000	 Speed: 860.79 img/s	Time: 0hrs:58min
# [2024-10-12 11:09:26 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.233,23552	LR: 0.009946	Loss: 0.000	Acc: 100.0000	 Speed: 820.29 img/s	Time: 0hrs:58min
# [2024-10-12 11:10:01 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.236,23808	LR: 0.009945	Loss: 0.000	Acc: 100.0000	 Speed: 866.57 img/s	Time: 0hrs:59min
# [2024-10-12 11:10:37 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.239,24064	LR: 0.009944	Loss: 0.000	Acc: 100.0000	 Speed: 852.93 img/s	Time: 1hrs:0min
# [2024-10-12 11:11:14 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.241,24320	LR: 0.009943	Loss: 0.000	Acc: 100.0000	 Speed: 849.89 img/s	Time: 1hrs:0min
# [2024-10-12 11:11:50 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.244,24576	LR: 0.009942	Loss: 0.000	Acc: 100.0000	 Speed: 840.74 img/s	Time: 1hrs:1min
# [2024-10-12 11:12:26 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.246,24832	LR: 0.009940	Loss: 0.000	Acc: 100.0000	 Speed: 859.40 img/s	Time: 1hrs:1min
# [2024-10-12 11:13:02 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.249,25088	LR: 0.009939	Loss: 0.000	Acc: 100.0000	 Speed: 844.95 img/s	Time: 1hrs:2min
# [2024-10-12 11:13:38 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.251,25344	LR: 0.009938	Loss: 0.000	Acc: 100.0000	 Speed: 857.10 img/s	Time: 1hrs:3min
# [2024-10-12 11:14:15 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.254,25600	LR: 0.009937	Loss: 0.000	Acc: 100.0000	 Speed: 844.19 img/s	Time: 1hrs:3min
# [2024-10-12 11:14:50 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.256,25856	LR: 0.009935	Loss: 0.000	Acc: 100.0000	 Speed: 859.69 img/s	Time: 1hrs:4min
# [2024-10-12 11:15:27 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.259,26112	LR: 0.009934	Loss: 0.000	Acc: 100.0000	 Speed: 842.24 img/s	Time: 1hrs:4min
# [2024-10-12 11:16:03 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.261,26368	LR: 0.009933	Loss: 0.000	Acc: 100.0000	 Speed: 843.10 img/s	Time: 1hrs:5min
# [2024-10-12 11:16:39 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.264,26624	LR: 0.009931	Loss: 0.000	Acc: 100.0000	 Speed: 854.73 img/s	Time: 1hrs:6min
# [2024-10-12 11:17:14 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.266,26880	LR: 0.009930	Loss: 0.000	Acc: 100.0000	 Speed: 874.54 img/s	Time: 1hrs:6min
# [2024-10-12 11:17:51 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.269,27136	LR: 0.009929	Loss: 0.000	Acc: 100.0000	 Speed: 828.01 img/s	Time: 1hrs:7min
# [2024-10-12 11:18:27 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.272,27392	LR: 0.009927	Loss: 0.000	Acc: 100.0000	 Speed: 851.28 img/s	Time: 1hrs:7min
# [2024-10-12 11:19:03 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.274,27648	LR: 0.009926	Loss: 0.000	Acc: 100.0000	 Speed: 857.96 img/s	Time: 1hrs:8min
# [2024-10-12 11:19:40 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.277,27904	LR: 0.009925	Loss: 0.000	Acc: 100.0000	 Speed: 836.63 img/s	Time: 1hrs:9min
# [2024-10-12 11:20:16 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.279,28160	LR: 0.009923	Loss: 0.000	Acc: 100.0000	 Speed: 842.45 img/s	Time: 1hrs:9min
# [2024-10-12 11:20:52 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.282,28416	LR: 0.009922	Loss: 0.000	Acc: 100.0000	 Speed: 854.69 img/s	Time: 1hrs:10min
# [2024-10-12 11:21:29 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.284,28672	LR: 0.009921	Loss: 0.000	Acc: 100.0000	 Speed: 847.61 img/s	Time: 1hrs:11min
# [2024-10-12 11:22:05 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.287,28928	LR: 0.009919	Loss: 0.000	Acc: 100.0000	 Speed: 852.90 img/s	Time: 1hrs:11min
# [2024-10-12 11:22:42 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.289,29184	LR: 0.009918	Loss: 0.000	Acc: 100.0000	 Speed: 830.34 img/s	Time: 1hrs:12min
# [2024-10-12 11:23:17 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.292,29440	LR: 0.009916	Loss: 0.000	Acc: 100.0000	 Speed: 861.30 img/s	Time: 1hrs:12min
# [2024-10-12 11:23:52 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.294,29696	LR: 0.009915	Loss: 0.000	Acc: 100.0000	 Speed: 874.57 img/s	Time: 1hrs:13min
# [2024-10-12 11:24:29 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.297,29952	LR: 0.009913	Loss: 0.000	Acc: 100.0000	 Speed: 848.95 img/s	Time: 1hrs:14min
# [2024-10-12 11:25:04 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.299,30208	LR: 0.009912	Loss: 0.000	Acc: 100.0000	 Speed: 863.02 img/s	Time: 1hrs:14min
# [2024-10-12 11:25:40 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.302,30464	LR: 0.009910	Loss: 0.000	Acc: 100.0000	 Speed: 847.85 img/s	Time: 1hrs:15min
# [2024-10-12 11:26:17 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.304,30720	LR: 0.009909	Loss: 0.000	Acc: 100.0000	 Speed: 847.71 img/s	Time: 1hrs:15min
# [2024-10-12 11:26:53 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.307,30976	LR: 0.009907	Loss: 0.000	Acc: 100.0000	 Speed: 840.56 img/s	Time: 1hrs:16min
# [2024-10-12 11:27:30 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.310,31232	LR: 0.009906	Loss: 0.000	Acc: 100.0000	 Speed: 843.33 img/s	Time: 1hrs:17min
# [2024-10-12 11:28:06 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.312,31488	LR: 0.009904	Loss: 0.000	Acc: 100.0000	 Speed: 842.59 img/s	Time: 1hrs:17min
# [2024-10-12 11:28:43 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.315,31744	LR: 0.009903	Loss: 0.000	Acc: 100.0000	 Speed: 843.31 img/s	Time: 1hrs:18min
# [2024-10-12 11:29:19 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.317,32000	LR: 0.009901	Loss: 0.000	Acc: 100.0000	 Speed: 845.54 img/s	Time: 1hrs:18min
# [2024-10-12 11:29:55 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.320,32256	LR: 0.009899	Loss: 0.000	Acc: 100.0000	 Speed: 839.69 img/s	Time: 1hrs:19min
# [2024-10-12 11:30:32 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.322,32512	LR: 0.009898	Loss: 0.000	Acc: 100.0000	 Speed: 839.12 img/s	Time: 1hrs:20min
# [2024-10-12 11:31:09 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.325,32768	LR: 0.009896	Loss: 0.000	Acc: 100.0000	 Speed: 834.19 img/s	Time: 1hrs:20min
# [2024-10-12 11:31:45 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.327,33024	LR: 0.009895	Loss: 0.000	Acc: 100.0000	 Speed: 841.85 img/s	Time: 1hrs:21min
# [2024-10-12 11:32:24 - <frozen onekey_algo.classification.run_classification>: 196]	INFO	Phase: train	Epoch: 0.330,33280	LR: 0.009893	Loss: 0.000	Acc: 100.0000	 Speed: 796.82 img/s	Time: 1hrs:21min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25092\452827886.py in <module>
#      35 # 训练模型
#      36 Args = namedtuple("Args", params)
# ---> 37 clf_main(Args(**params))
#
# ~\Desktop\OnekeyPlatform\onekey_envs\lib\site-packages\onekey_algo\classification\run_classification.py in main(args)
#
# ~\Desktop\OnekeyPlatform\onekey_envs\lib\site-packages\onekey_algo\classification\run_classification.py in train_model(model, device, dataloaders, batch_size, criterion, optimizer, lr_scheduler, num_epochs, iters_start, iters_verbose, save_dir, is_inception, save_per_epoch, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Folder模式
#
# 在Onekey中Folder模式一般是采用手动拖拽标注出来的结果。
#
# * `train_dir`，训练数据存放的文件夹。
# * `val_dir`，验证数据存放的文件夹。
# * `labels_file`，label的集合，表明训练数据多少标签，
#     > 注意：在train_dir和val_dir下面必须存在相应数据量的子文件夹。

# %%
## 获得视频教程
from onekey_algo.custom.Manager import onekey_show
onekey_show('What概览|Folder')

# %%
import os
from onekey_algo.classification.run_classification import main as clf_main
from collections import namedtuple

# 设置参数
root_dir = r'自己数据的目录'

train_dir = os.path.join(root_dir, 'train')
val_dir = os.path.join(root_dir, 'val')
labels_file = os.path.join(root_dir, 'labels.txt')
params = dict(train=train_dir,
              valid=val_dir,
              labels_file=labels_file,
              data_pattern=None,
              j=0,
              max2use=None,
              val_max2use=None,
              batch_balance=False,
              normalize_method='imagenet',
              model_name='resnet50',
              gpus=[0],
              batch_size=8,
              epochs=3,
              init_lr=0.1,
              optimizer='sgd',
              retrain=None,
              model_root='.',
              add_date=False,
              iters_start=0,
              iters_verbose=1,
              save_per_epoch=False,
              pretrained=True)
# 训练模型
Args = namedtuple("Args", params)
clf_main(Args(**params))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27520\910705246.py in <module>
#      33 # 训练模型
#      34 Args = namedtuple("Args", params)
# ---> 35 clf_main(Args(**params))
#
# ~\Desktop\OnekeyPlatform\onekey_envs\lib\site-packages\onekey_algo\classification\run_classification.py in main(args)
#
# ~\Desktop\OnekeyPlatform\onekey_envs\lib\site-packages\onekey_algo\classification\run_classification.py in __config_list_or_folder_dataset(records, data_pattern)
#
# ValueError: records(['自己数据的目录\\train']) or data_pattern(None) config error! 大概率是文件不存在！
